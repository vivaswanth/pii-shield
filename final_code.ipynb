# %%
import cv2
import random
import string
import os
import pytesseract
from faker import Faker

faker = Faker()

def generate_fake_pan_data():
    return {
        "docType": "Pan",
        "name": faker.name().upper(),
        "fatherName": faker.name().upper(),
        "dob": faker.date_of_birth(minimum_age=18, maximum_age=60).strftime("%d/%m/%Y"),
        "docId": ''.join(random.choices(string.ascii_uppercase, k=5)) +
                 ''.join(random.choices(string.digits, k=4)) +
                 random.choice(string.ascii_uppercase),
        "side": "Front",
        "orientation": "0",
        "isColoured": "Coloured"
    }

def generate_fake_pan_image(template_path, output_path, fake_data):
    img = cv2.imread(template_path)

    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 1.0
    color = (0, 0, 0)
    thickness = 2

    # Overlay text at approximate PAN card positions
    cv2.putText(img, fake_data["name"], (80, 420), font, font_scale, color, thickness)
    cv2.putText(img, fake_data["fatherName"], (80, 500), font, font_scale, color, thickness)
    cv2.putText(img, fake_data["dob"], (80, 600), font, font_scale, color, thickness)
    cv2.putText(img, fake_data["docId"], (300, 300), font, font_scale, color, thickness)

    cv2.imwrite(output_path, img)

def generate_bulk_pan_images(template_path, output_dir="synthetic_pan_samples_latest", count=100):
    os.makedirs(output_dir, exist_ok=True)
    synthetic_data_list = []

    for i in range(count):
        fake_data = generate_fake_pan_data()
        filename = f"synthetic_pan_{i:03d}.jpg"
        output_path = os.path.join(output_dir, filename)
        generate_fake_pan_image(template_path, output_path, fake_data)
        synthetic_data_list.append(fake_data)
        print(f"✅ Saved: {filename}")

    print(f"\n🎉 Successfully generated {count} synthetic PAN card images.")
    return synthetic_data_list

# Generate and store synthetic data
template_path = "blank_pan_template - Copy.jpg"
synthetic_data_list = generate_bulk_pan_images(template_path)
























def run_ocr(img_path):
    img = cv2.imread(img_path)
    data = pytesseract.image_to_data(img, output_type=pytesseract.Output.DICT, lang="eng")
    return img, data

def redact_image_by_fields(img, ocr_data, pii_fields):
    # Flatten all PII values into a list
    pii_values = [v.strip().lower() for v in pii_fields.values() if isinstance(v, str)]
    #print("pii_values",pii_values)

    for i, word in enumerate(ocr_data["text"]):
        word_clean = word.strip().lower()
        if word_clean and any(pii in word_clean or word_clean in pii for pii in pii_values):
            x, y, w, h = (
                ocr_data["left"][i],
                ocr_data["top"][i],
                ocr_data["width"][i],
                ocr_data["height"][i],
            )
            cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 0), -1)  # blackout

       
    
    return img  



def redact_doc_with_known_fields(img_path, output_path, known_fields):
    img, ocr_data = run_ocr(img_path)
    redacted_img = redact_image_by_fields(img, ocr_data, known_fields)
    cv2.imwrite(output_path, redacted_img)
    print("✅ Redacted image saved at:", output_path)
    return output_path
    

# def batch_redact_pan_images_with_known_data(synthetic_data_list,input_dir="synthetic_pan_samples_latest_1",
#                                             output_dir="redacted_pan_samples_1"
#                                             ):
#     os.makedirs(output_dir, exist_ok=True)
#     redacted_data = []

#     for i, filename in enumerate(sorted(os.listdir(input_dir))):
#         if filename.lower().endswith(".jpg"):
#             input_path = os.path.join(input_dir, filename)
#             output_path = os.path.join(output_dir, f"redacted_{filename}")

#             try:
#                 known_fields = synthetic_data_list[i]  # match index to filename
#                 redact_doc_with_known_fields(input_path, output_path, known_fields)
#                 redacted_data.append({
#                     "filename": filename,
#                     "redacted_path": output_path,
#                     "redacted_fields": known_fields
#                 })
#                 print(f"✅ Redacted: {filename}")
#             except Exception as e:
#                 print(f"❌ Failed to redact {filename}: {e}")

#     print(f"\n🎉 Completed redaction for {len(redacted_data)} PAN images.")
#     return redacted_data

# After generating synthetic images

# for i in range(5):
#     #data = generate_fake_pan_data()
#     # Save image using this data
#     output_path = f"synthetic_pan_samples_latest/synthetic_pan_{i:03d}.jpg"
#     generate_fake_pan_image(template_path, output_path, data)
#     synthetic_data_list.append(data)

import json

def batch_redact_pan_images_with_known_data(synthetic_data_list,
                                            input_dir="synthetic_pan_samples_latest",
                                            output_dir="redacted_pan_samples"):
    os.makedirs(output_dir, exist_ok=True)
    redacted_data = []

    for i, filename in enumerate(sorted(os.listdir(input_dir))):
        if filename.lower().endswith(".jpg"):
            input_path = os.path.join(input_dir, filename)
            redacted_filename = f"redacted_{filename}"
            output_path = os.path.join(output_dir, redacted_filename)
            json_path = os.path.join(output_dir, redacted_filename.replace(".jpg", ".json"))

            try:
                known_fields = synthetic_data_list[i]  # match index to filename
                redact_doc_with_known_fields(input_path, output_path, known_fields)

                # Save metadata as JSON
                with open(json_path, "w") as f:
                    json.dump(known_fields, f, indent=4)

                redacted_data.append({
                    "filename": filename,
                    "redacted_path": output_path,
                    "json_path": json_path,
                    "redacted_fields": known_fields
                })
                print(f"✅ Redacted: {filename} and saved JSON: {json_path}")
            except Exception as e:
                print(f"❌ Failed to redact {filename}: {e}")

    print(f"\n🎉 Completed redaction for {len(redacted_data)} PAN images.")
    return redacted_data


# Then redact using known fields
batch_redact_pan_images_with_known_data(synthetic_data_list=synthetic_data_list)
# Out:
# ✅ Saved: synthetic_pan_000.jpg
# ✅ Saved: synthetic_pan_001.jpg
# ✅ Saved: synthetic_pan_002.jpg
# ✅ Saved: synthetic_pan_003.jpg
# ✅ Saved: synthetic_pan_004.jpg
# ✅ Saved: synthetic_pan_005.jpg
# ✅ Saved: synthetic_pan_006.jpg
# ✅ Saved: synthetic_pan_007.jpg
# ✅ Saved: synthetic_pan_008.jpg
# ✅ Saved: synthetic_pan_009.jpg
# ✅ Saved: synthetic_pan_010.jpg
# ✅ Saved: synthetic_pan_011.jpg
# ✅ Saved: synthetic_pan_012.jpg
# ✅ Saved: synthetic_pan_013.jpg
# ✅ Saved: synthetic_pan_014.jpg
# ✅ Saved: synthetic_pan_015.jpg
# ✅ Saved: synthetic_pan_016.jpg
# ✅ Saved: synthetic_pan_017.jpg
# ✅ Saved: synthetic_pan_018.jpg
# ✅ Saved: synthetic_pan_019.jpg
# ✅ Saved: synthetic_pan_020.jpg
# ✅ Saved: synthetic_pan_021.jpg
# ✅ Saved: synthetic_pan_022.jpg
# ✅ Saved: synthetic_pan_023.jpg
# ✅ Saved: synthetic_pan_024.jpg
# ✅ Saved: synthetic_pan_025.jpg
json
# ✅ Redacted image saved at: redacted_pan_samples/redacted_synthetic_pan_088.jpg
# ✅ Redacted: synthetic_pan_088.jpg and saved JSON: redacted_pan_samples/redacted_synthetic_pan_088.json
# ✅ Redacted image saved at: redacted_pan_samples/redacted_synthetic_pan_089.jpg
# ✅ Redacted: synthetic_pan_089.jpg and saved JSON: redacted_pan_samples/redacted_synthetic_pan_089.json
# ✅ Redacted image saved at: redacted_pan_samples/redacted_synthetic_pan_090.jpg
# ✅ Redacted: synthetic_pan_090.jpg and saved JSON: redacted_pan_samples/redacted_synthetic_pan_090.json
# ✅ Redacted image saved at: redacted_pan_samples/redacted_synthetic_pan_091.jpg
# ✅ Redacted: synthetic_pan_091.jpg and saved JSON: redacted_pan_samples/redacted_synthetic_pan_091.json
# ✅ Redacted image saved at: redacted_pan_samples/redacted_synthetic_pan_092.jpg
# ✅ Redacted: synthetic_pan_092.jpg and saved JSON: redacted_pan_samples/redacted_synthetic_pan_092.json
# ✅ Redacted image saved at: redacted_pan_samples/redacted_synthetic_pan_093.jpg
# ✅ Redacted: synthetic_pan_093.jpg and saved JSON: redacted_pan_samples/redacted_synthetic_pan_093.json
# ✅ Redacted image saved at: redacted_pan_samples/redacted_synthetic_pan_094.jpg
# ✅ Redacted: synthetic_pan_094.jpg and saved JSON: redacted_pan_samples/redacted_synthetic_pan_094.json
# ✅ Redacted image saved at: redacted_pan_samples/redacted_synthetic_pan_095.jpg
# ✅ Redacted: synthetic_pan_095.jpg and saved JSON: redacted_pan_samples/redacted_synthetic_pan_095.json
# ✅ Redacted image saved at: redacted_pan_samples/redacted_synthetic_pan_096.jpg
# ✅ Redacted: synthetic_pan_096.jpg and saved JSON: redacted_pan_samples/redacted_synthetic_pan_096.json
# ✅ Redacted image saved at: redacted_pan_samples/redacted_synthetic_pan_097.jpg
# ✅ Redacted: synthetic_pan_097.jpg and saved JSON: redacted_pan_samples/redacted_synthetic_pan_097.json
# ✅ Redacted image saved at: redacted_pan_samples/redacted_synthetic_pan_098.jpg
# ✅ Redacted: synthetic_pan_098.jpg and saved JSON: redacted_pan_samples/redacted_synthetic_pan_098.json
# ✅ Redacted image saved at: redacted_pan_samples/redacted_synthetic_pan_099.jpg
# ✅ Redacted: synthetic_pan_099.jpg and saved JSON: redacted_pan_samples/redacted_synthetic_pan_099.json
#
# 🎉 Completed redaction for 100 PAN images.
# [{'filename': 'synthetic_pan_000.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_000.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_000.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'DANIEL OLSEN',
#    'fatherName': 'ANDREW WRIGHT',
#    'dob': '06/11/1998',
#    'docId': 'UMFCY8161C',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_001.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_001.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_001.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'TAMARA MURPHY',
#    'fatherName': 'LORI SHERMAN',
#    'dob': '21/02/2004',
#    'docId': 'LSWKO3066Z',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_002.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_002.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_002.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'ERIC MEADOWS DDS',
#    'fatherName': 'ASHLEY NEAL',
#    'dob': '28/01/1981',
#    'docId': 'BNOFW9520H',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_003.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_003.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_003.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'RONALD LEON',
#    'fatherName': 'TINA HEBERT',
#    'dob': '01/12/1995',
#    'docId': 'OPLKI3675L',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_004.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_004.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_004.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'LACEY DUKE',
#    'fatherName': 'PATRICIA FORBES',
#    'dob': '01/02/1985',
#    'docId': 'OCWOE5202O',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_005.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_005.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_005.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'AARON BAKER',
#    'fatherName': 'CHRISTOPHER INGRAM',
#    'dob': '06/01/1982',
#    'docId': 'GWBBO2569M',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_006.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_006.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_006.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'ERIK PERRY',
#    'fatherName': 'CAROL DRAKE',
#    'dob': '15/03/1998',
#    'docId': 'FXROI4446I',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_007.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_007.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_007.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'RONALD MEJIA',
#    'fatherName': 'ROBERT HALL',
#    'dob': '25/12/1971',
#    'docId': 'VWOSM2547B',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_008.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_008.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_008.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'STEVEN PACHECO',
#    'fatherName': 'JUAN BURKE',
#    'dob': '22/10/2000',
#    'docId': 'KQHEP5740X',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_009.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_009.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_009.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'STEVEN DOUGLAS',
#    'fatherName': 'JUSTIN PALMER',
#    'dob': '21/02/2001',
#    'docId': 'LIXHE1031G',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_010.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_010.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_010.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'ELAINE CAREY',
#    'fatherName': 'HEATHER STANTON',
#    'dob': '20/03/1976',
#    'docId': 'DOORE8393F',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_011.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_011.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_011.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'PAUL JACKSON',
#    'fatherName': 'ADAM PEREZ',
#    'dob': '15/10/1997',
#    'docId': 'QFHTV8093Y',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_012.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_012.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_012.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'WILLIAM BALLARD',
#    'fatherName': 'ALEXANDRA JACKSON',
#    'dob': '06/10/1971',
#    'docId': 'YZMPW6987L',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_013.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_013.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_013.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'CYNTHIA JACKSON',
#    'fatherName': 'PATRICK LEWIS',
#    'dob': '27/08/1995',
#    'docId': 'LVXDO9747P',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_014.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_014.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_014.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'WYATT WILSON',
#    'fatherName': 'DANIEL MASON',
#    'dob': '15/05/1969',
#    'docId': 'NPCGB8301K',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_015.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_015.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_015.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'KENNETH REID',
#    'fatherName': 'CHRISTINA BOWMAN',
#    'dob': '09/02/2004',
#    'docId': 'CCZNS9073D',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_016.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_016.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_016.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'MIKE SPENCER',
#    'fatherName': 'DAVID POWERS',
#    'dob': '20/03/1976',
#    'docId': 'MGDAX4956X',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_017.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_017.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_017.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'DENISE KIM',
#    'fatherName': 'KAREN DAWSON',
#    'dob': '12/12/1979',
#    'docId': 'PXVYJ4275Y',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_018.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_018.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_018.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'SARA ANDERSON',
#    'fatherName': 'SHARI HARRIS',
#    'dob': '22/01/1984',
#    'docId': 'ZDGRZ8749A',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_019.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_019.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_019.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'JOSEPH RODRIGUEZ',
#    'fatherName': 'LAURA WALSH',
#    'dob': '30/11/1983',
#    'docId': 'UDDRR7779A',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_020.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_020.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_020.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'RICHARD TOWNSEND',
#    'fatherName': 'MRS. TERESA LAM',
#    'dob': '10/07/1975',
#    'docId': 'YYEVZ3323Z',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_021.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_021.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_021.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'LINDSAY RICHARDSON',
#    'fatherName': 'JAMES PADILLA',
#    'dob': '18/01/1995',
#    'docId': 'GFDUM6088O',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_022.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_022.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_022.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'LORETTA CLARK',
#    'fatherName': 'ANTHONY ARNOLD',
#    'dob': '29/06/1974',
#    'docId': 'NYSMT7051R',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_023.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_023.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_023.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'ANTHONY JOHNSON',
#    'fatherName': 'CHRISTOPHER MOORE',
#    'dob': '17/09/1991',
#    'docId': 'FIJRA6256F',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_024.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_024.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_024.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'DESIREE WILLIAMS',
#    'fatherName': 'STACY NICHOLS',
#    'dob': '17/12/1970',
#    'docId': 'ZHRKL5436U',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_025.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_025.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_025.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'TRACY REID',
#    'fatherName': 'NICHOLAS MAXWELL',
#    'dob': '21/03/1994',
#    'docId': 'OYNCC1044S',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_026.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_026.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_026.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'JIMMY ROMERO',
#    'fatherName': 'MS. ERICA PIERCE',
#    'dob': '09/11/1999',
#    'docId': 'HARWY9269Q',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_027.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_027.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_027.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'MARIE STEWART',
#    'fatherName': 'RICHARD GONZALEZ',
#    'dob': '13/09/1992',
#    'docId': 'TYPTI5896O',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_028.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_028.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_028.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'JAMES WOOD',
#    'fatherName': 'ROBERT THOMPSON',
#    'dob': '30/04/1965',
#    'docId': 'EOWZJ9452S',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_029.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_029.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_029.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'AMY LAM',
#    'fatherName': 'DENISE KERR',
#    'dob': '14/10/2001',
#    'docId': 'AESSI1985A',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_030.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_030.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_030.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'DAVID SAUNDERS',
#    'fatherName': 'ANTHONY HILL',
#    'dob': '28/09/1997',
#    'docId': 'IAIDU7707B',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_031.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_031.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_031.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'MICHAEL ROBERTSON',
#    'fatherName': 'MATTHEW SMITH',
#    'dob': '15/09/1981',
#    'docId': 'XISXH7338J',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_032.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_032.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_032.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'ROBERT TAYLOR',
#    'fatherName': 'ALEXANDRA BEAN',
#    'dob': '24/07/1983',
#    'docId': 'YBSAI4446V',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_033.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_033.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_033.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'LISA KHAN',
#    'fatherName': 'AUSTIN JONES',
#    'dob': '08/03/2000',
#    'docId': 'QBHDT8418X',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_034.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_034.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_034.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'WILLIAM REED',
#    'fatherName': 'CRISTINA WILLIAMS',
#    'dob': '20/12/1989',
#    'docId': 'UVGGH0586V',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_035.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_035.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_035.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'LAWRENCE STAFFORD DDS',
#    'fatherName': 'MATTHEW DAVIS',
#    'dob': '29/06/2003',
#    'docId': 'STJXD5180K',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_036.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_036.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_036.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'ERICA CHAPMAN',
#    'fatherName': 'DAVID GONZALEZ',
#    'dob': '19/01/1982',
#    'docId': 'OGJTD5983H',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_037.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_037.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_037.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'DANIELLE SCOTT',
#    'fatherName': 'NANCY FOX',
#    'dob': '10/01/2000',
#    'docId': 'KDKLK6152H',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_038.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_038.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_038.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'MELANIE MOORE',
#    'fatherName': 'STEVEN DAVIS',
#    'dob': '18/11/1972',
#    'docId': 'JGIDE4858O',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_039.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_039.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_039.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'BRIAN CARROLL',
#    'fatherName': 'JOSEPH SHEPARD',
#    'dob': '06/02/1967',
#    'docId': 'HCCHH5868W',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_040.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_040.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_040.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'GREGORY JOHNSON',
#    'fatherName': 'VINCENT HENRY',
#    'dob': '27/03/1972',
#    'docId': 'KZIZP8915S',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_041.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_041.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_041.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'MARTIN PARKER',
#    'fatherName': 'MARY CHURCH',
#    'dob': '08/08/2003',
#    'docId': 'SRFYK4712D',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_042.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_042.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_042.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'REBECCA KIRBY',
#    'fatherName': 'DANIELLE THOMAS',
#    'dob': '27/12/1999',
#    'docId': 'MSPXU8848Y',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_043.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_043.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_043.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'DEBBIE THOMPSON',
#    'fatherName': 'WILLIAM ANDERSON',
#    'dob': '23/09/1978',
#    'docId': 'LBDCM1797E',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_044.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_044.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_044.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'ROSE JONES',
#    'fatherName': 'ARIANA PARKS',
#    'dob': '25/11/1975',
#    'docId': 'OZYAP2767X',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_045.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_045.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_045.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'TAMARA WAGNER',
#    'fatherName': 'MATTHEW MEDINA',
#    'dob': '20/05/1970',
#    'docId': 'XSPEX4293G',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_046.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_046.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_046.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'TAYLOR CURTIS',
#    'fatherName': 'HEATHER ROSE',
#    'dob': '05/05/1967',
#    'docId': 'ZYZCM5883R',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_047.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_047.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_047.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'MARK WILLIAMS',
#    'fatherName': 'TAYLOR BROOKS',
#    'dob': '07/08/1986',
#    'docId': 'REWJC6318O',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_048.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_048.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_048.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'JAMES POPE',
#    'fatherName': 'LUCAS LARSON',
#    'dob': '30/09/2006',
#    'docId': 'CTNRC0253A',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_049.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_049.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_049.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'AMY HARRINGTON',
#    'fatherName': 'JESSICA DAVIS',
#    'dob': '13/12/1979',
#    'docId': 'TDBNN6895S',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_050.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_050.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_050.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'VINCENT PATRICK',
#    'fatherName': 'KIMBERLY BENITEZ',
#    'dob': '27/03/1975',
#    'docId': 'UTKOH5607A',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_051.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_051.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_051.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'TANYA RICHMOND',
#    'fatherName': 'KRISTY SMITH',
#    'dob': '23/04/1989',
#    'docId': 'BXXOQ1642E',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_052.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_052.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_052.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'HEATHER THOMAS',
#    'fatherName': 'LORI VALENCIA',
#    'dob': '11/06/2005',
#    'docId': 'AUEYL7000E',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_053.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_053.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_053.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'BRIAN COLEMAN',
#    'fatherName': 'GINA GROSS',
#    'dob': '14/02/2002',
#    'docId': 'EPXZW1326V',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_054.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_054.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_054.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'TANYA RAMIREZ',
#    'fatherName': 'CHASE ANDERSON',
#    'dob': '28/10/1994',
#    'docId': 'RZXGY8607N',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_055.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_055.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_055.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'LISA ALVAREZ',
#    'fatherName': 'ALLISON SMALL',
#    'dob': '08/08/1977',
#    'docId': 'HPDBV2200D',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_056.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_056.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_056.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'NATASHA FLOWERS',
#    'fatherName': 'SHEENA SAMPSON',
#    'dob': '29/04/2007',
#    'docId': 'HRUXB4130S',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_057.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_057.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_057.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'JILLIAN REED',
#    'fatherName': 'TAYLOR SMITH',
#    'dob': '25/05/1993',
#    'docId': 'JZYCQ2442O',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_058.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_058.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_058.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'ROBERT ROBERTS',
#    'fatherName': 'MONIQUE COMBS',
#    'dob': '29/08/1980',
#    'docId': 'JVTSF9554J',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_059.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_059.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_059.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'CRAIG PHAM',
#    'fatherName': 'LAURA PACHECO',
#    'dob': '04/12/1987',
#    'docId': 'GWTWH8492P',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_060.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_060.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_060.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'MELINDA GUTIERREZ',
#    'fatherName': 'TERESA ARNOLD',
#    'dob': '09/09/1991',
#    'docId': 'ARKSN7363A',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_061.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_061.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_061.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'MERCEDES JENSEN',
#    'fatherName': 'ANGELA DANIELS',
#    'dob': '11/07/1969',
#    'docId': 'VZMIO7273U',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_062.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_062.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_062.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'AMY WATSON',
#    'fatherName': 'MARY DAVIS',
#    'dob': '11/02/2006',
#    'docId': 'VKHYZ8171S',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_063.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_063.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_063.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'CHRISTOPHER HORNE',
#    'fatherName': 'CHRISTIAN VILLA',
#    'dob': '01/07/2004',
#    'docId': 'JAJXC6876V',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_064.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_064.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_064.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'ANDREW LUCAS',
#    'fatherName': 'ELIZABETH HAAS',
#    'dob': '22/04/2007',
#    'docId': 'EWTAN1732A',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_065.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_065.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_065.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'JESSICA ALVARADO',
#    'fatherName': 'DANIEL HUNT',
#    'dob': '30/06/2006',
#    'docId': 'ZLQEO4237J',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_066.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_066.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_066.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'JEREMY STEWART',
#    'fatherName': 'WILLIAM WELLS',
#    'dob': '30/07/1977',
#    'docId': 'RCBLT0695T',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_067.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_067.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_067.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'LEE DONOVAN',
#    'fatherName': 'RACHEL BRAUN',
#    'dob': '16/01/1995',
#    'docId': 'WSRXK3632O',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_068.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_068.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_068.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'WILLIAM HUNT',
#    'fatherName': 'JOSEPH KLEIN',
#    'dob': '17/10/1970',
#    'docId': 'BAQEK4525I',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_069.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_069.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_069.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'JASON STEWART',
#    'fatherName': 'TIMOTHY MORSE',
#    'dob': '07/11/2003',
#    'docId': 'DTBQZ3057Z',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_070.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_070.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_070.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'ADRIAN CHAVEZ',
#    'fatherName': 'KIMBERLY VEGA',
#    'dob': '11/11/1990',
#    'docId': 'ZPKRH3006W',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_071.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_071.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_071.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'BETH MUNOZ',
#    'fatherName': 'TIMOTHY MILLER',
#    'dob': '10/07/1969',
#    'docId': 'JZMND0589R',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_072.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_072.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_072.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'PAULA JACKSON',
#    'fatherName': 'ALLEN GRAHAM',
#    'dob': '22/11/1972',
#    'docId': 'YWZQS3289N',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_073.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_073.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_073.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'LEONARD TRAN',
#    'fatherName': 'PATRICK SIMPSON',
#    'dob': '14/07/1965',
#    'docId': 'KPVXX6505O',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_074.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_074.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_074.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'DANIEL THOMPSON',
#    'fatherName': 'MR. MATTHEW HARRIS',
#    'dob': '04/06/2002',
#    'docId': 'LLZNL6522Q',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_075.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_075.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_075.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'THERESA LONG',
#    'fatherName': 'RICHARD WILSON',
#    'dob': '15/03/1991',
#    'docId': 'ORKTP1046F',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_076.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_076.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_076.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'MICHAELA GREENE',
#    'fatherName': 'NATHAN CAMPBELL',
#    'dob': '24/06/1999',
#    'docId': 'QYBXW2835N',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_077.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_077.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_077.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'CATHERINE WATKINS',
#    'fatherName': 'KIMBERLY WARREN',
#    'dob': '02/11/1998',
#    'docId': 'VSNDY5968G',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_078.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_078.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_078.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'MICHELLE FLORES',
#    'fatherName': 'RYAN SOLOMON',
#    'dob': '30/04/1967',
#    'docId': 'FHMGH2020D',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_079.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_079.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_079.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'MALLORY JEFFERSON',
#    'fatherName': 'ROBERT MCCORMICK',
#    'dob': '13/12/1994',
#    'docId': 'IRCLM0059U',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_080.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_080.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_080.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'CHAD JONES',
#    'fatherName': 'CURTIS GALLAGHER',
#    'dob': '18/02/1967',
#    'docId': 'HZKYA1970I',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_081.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_081.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_081.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'JACOB HARRIS',
#    'fatherName': 'ASHLEY BAUER',
#    'dob': '02/10/1979',
#    'docId': 'OZYHN3346B',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_082.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_082.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_082.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'BRANDON HAWKINS',
#    'fatherName': 'OLIVIA ANDERSON',
#    'dob': '08/04/2007',
#    'docId': 'WWKVU7968A',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_083.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_083.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_083.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'RICARDO KANE',
#    'fatherName': 'DANIEL REYNOLDS',
#    'dob': '12/12/2001',
#    'docId': 'MIWFQ1080F',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_084.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_084.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_084.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'MICHAEL SANDERS',
#    'fatherName': 'DWAYNE MURPHY',
#    'dob': '03/03/2000',
#    'docId': 'GPGFE6289Z',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_085.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_085.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_085.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'ADAM HINES',
#    'fatherName': 'JAMES FRANCIS',
#    'dob': '25/06/1983',
#    'docId': 'MQXZL2796A',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_086.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_086.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_086.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'APRIL HURLEY',
#    'fatherName': 'LAURA CLARK',
#    'dob': '16/08/1967',
#    'docId': 'KWETL9411Y',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_087.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_087.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_087.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'TOM JONES',
#    'fatherName': 'RAYMOND MORALES',
#    'dob': '30/06/1975',
#    'docId': 'IHJEC9252U',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_088.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_088.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_088.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'JOANN THOMPSON',
#    'fatherName': 'JAMES NELSON',
#    'dob': '22/07/1993',
#    'docId': 'APMIJ3485O',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_089.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_089.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_089.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'PAUL DRAKE',
#    'fatherName': 'VANESSA CASTILLO',
#    'dob': '28/02/1991',
#    'docId': 'LEBDZ9917L',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_090.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_090.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_090.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'GREGORY SANDERS',
#    'fatherName': 'MELISSA CANNON',
#    'dob': '19/09/1968',
#    'docId': 'UDIEO1887M',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_091.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_091.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_091.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'JEFF REEVES',
#    'fatherName': 'MADISON LIVINGSTON',
#    'dob': '12/01/1985',
#    'docId': 'YMUNS1433S',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_092.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_092.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_092.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'MATTHEW MULLINS',
#    'fatherName': 'STEPHEN BAKER',
#    'dob': '04/10/1983',
#    'docId': 'MVCPE5175O',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_093.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_093.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_093.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'OLIVIA LONG',
#    'fatherName': 'REBECCA CRANE',
#    'dob': '26/01/1976',
#    'docId': 'YBWIA2221E',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_094.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_094.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_094.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'MARCUS WILLIAMSON',
#    'fatherName': 'MELISSA WALTERS',
#    'dob': '08/09/1969',
#    'docId': 'VKJCU4059T',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_095.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_095.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_095.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'JAIME LARSEN',
#    'fatherName': 'CHRISTOPHER PEREZ',
#    'dob': '22/12/1986',
#    'docId': 'IRHQA6918J',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_096.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_096.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_096.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'BETTY PRICE',
#    'fatherName': 'PAUL REYES',
#    'dob': '25/11/1985',
#    'docId': 'YKVOA1009X',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_097.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_097.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_097.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'NICOLE NAVARRO',
#    'fatherName': 'MR. NICHOLAS MILLER DDS',
#    'dob': '12/03/1987',
#    'docId': 'AVZTK0396X',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_098.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_098.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_098.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'CINDY JUAREZ',
#    'fatherName': 'ANGELA CHAPMAN',
#    'dob': '31/10/1965',
#    'docId': 'EFKYU7186H',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}},
#  {'filename': 'synthetic_pan_099.jpg',
#   'redacted_path': 'redacted_pan_samples/redacted_synthetic_pan_099.jpg',
#   'json_path': 'redacted_pan_samples/redacted_synthetic_pan_099.json',
#   'redacted_fields': {'docType': 'Pan',
#    'name': 'KYLE NAVARRO',
#    'fatherName': 'LAWRENCE FOWLER',
#    'dob': '23/08/1968',
#    'docId': 'JXCQB5963E',
#    'side': 'Front',
#    'orientation': '0',
#    'isColoured': 'Coloured'}}]

# %%
import json

def batch_redact_pan_images_with_known_data(synthetic_data_list,
                                            input_dir="synthetic_pan_samples_latest_1",
                                            output_dir="redacted_pan_samples_1"):
    os.makedirs(output_dir, exist_ok=True)
    redacted_data = []

    for i, filename in enumerate(sorted(os.listdir(input_dir))):
        if filename.lower().endswith(".jpg"):
            input_path = os.path.join(input_dir, filename)
            redacted_filename = f"redacted_{filename}"
            output_path = os.path.join(output_dir, redacted_filename)
            json_path = os.path.join(output_dir, redacted_filename.replace(".jpg", ".json"))

            try:
                known_fields = synthetic_data_list[i]  # match index to filename
                redact_doc_with_known_fields(input_path, output_path, known_fields)

                # Save metadata as JSON
                with open(json_path, "w") as f:
                    json.dump(known_fields, f, indent=4)

                redacted_data.append({
                    "filename": filename,
                    "redacted_path": output_path,
                    "json_path": json_path,
                    "redacted_fields": known_fields
                })
                print(f"✅ Redacted: {filename} and saved JSON: {json_path}")
            except Exception as e:
                print(f"❌ Failed to redact {filename}: {e}")

    print(f"\n🎉 Completed redaction for {len(redacted_data)} PAN images.")
    return redacted_data
